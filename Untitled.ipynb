# %%
import os
os.getcwd()
# Out:
# '/Users/brynndafoe/DSCI510/dsci510_fall2025_final_project'

# %%
with open("data/.gitkeep", "w") as f:
    pass

# %%
os.listdir("data")
# Out:
# ['W_2022_2',
#  'M_2015_1',
#  'M_2019_2',
#  'W_2019_2',
#  '.DS_Store',
#  'M_2022_2',
#  'W_2015_1',
#  'W_2025_3',
#  'W_2021_2',
#  'M_2016_1',
#  'Training_Data_Men.csv',
#  'cleaned',
#  'M_2018_1',
#  '.gitkeep',
#  'olympic_results',
#  'W_2018_1',
#  'AthleteData.csv',
#  'M_2021_2',
#  'World_Cup_URLs.csv',
#  'W_2016_1',
#  'M_2025_3',
#  'W_2024_3',
#  'M_2017_1',
#  'W_2020_2',
#  'W_2017_1',
#  'Testing_Data_Women.csv',
#  'Womens_Coefficients.csv',
#  'M_2020_2',
#  'Testing_Data_Men.csv',
#  'M_2024_3',
#  'FIS_scoresheet_pdfs',
#  'Training_Data_Women.csv',
#  '.ipynb_checkpoints',
#  'W_2023_3',
#  'Mens_Testing_Data_Ranked.csv',
#  'Womens_Testing_Data_Ranked.csv',
#  'Athlete_URLs.csv',
#  'Mens_Coefficients.csv',
#  'M_2023_3']
